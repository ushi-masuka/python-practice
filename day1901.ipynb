# %% [markdown]
# ## **Questions based on Titanic Dataset:**
#
# To read the dataset as csv, use the below code:
#
# ```python
# import pandas as pd
#
# url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv"
# titanic_df = pd.read_csv(url)
# ```

# %%
import numpy as np
import pandas as pd



url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv"
titanic_df = pd.read_csv(url)

# %% [markdown]
# ### `Q-1:` Using `groupby` make groups using the `"Pclass"` column and find out the average age and total number of missing values in the `"Age"` column for every group.

# %%
Pclass=titanic_df.groupby("Pclass")
Pclass.agg({"Age":["mean",lambda x: x.isnull().sum()]})
# Out:
#               Age
#              mean <lambda_0>
# Pclass
# 1       38.233441         30
# 2       29.877630         11
# 3       25.140620        136

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df[titanic_df["Embarked"].isnull()==True]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# ### `Q-2:` Using `groupby` make groups using the `"Pclass"` column and fill every group's `"Embarked"` column's missing values with the mode value of that group. After that, print every group's `"Embarked"` column's value counts in ascending order.

# %%
'''titanic_df.loc[titanic_df["Pclass"]==1]["Embarked"].fillna(Pclass.get_group(1)["Embarked"].mode(),inplace=True)'''
'''for group,data in Pclass:
  data["Embarked"]=data["Embarked"].fillna(data["Embarked"].mode()[0])'''
# Out:
# 'for group,data in Pclass:\n  data["Embarked"]=data["Embarked"].fillna(data["Embarked"].mode()[0])'

# %%
titanic_df["Embarked"]=titanic_df.groupby("Pclass")["Embarked"].transform(lambda x: x.fillna(x.mode()[0]))
titanic_df.groupby("Pclass")["Embarked"].value_counts().sort_values()
# Out:
# Pclass  Embarked
# 1       Q             2
# 2       Q             3
#         C            17
# 3       C            66
#         Q            72
# 1       C            85
#         S           129
# 2       S           164
# 3       S           353
# Name: count, dtype: int64

# %% [markdown]
# ### `Q-3:` Make groups based on `"Embarked"` column. And for each of this embarked group, make another group based on `"Pclass"` and find out the average fare (round off up to 2 decimal places) for each "Pclass" for each group of "Embarked".
#
# **Sample Output:**
#
# ```bash
# {'C': {1: 105, 2: 25, 3: 11},
#  'Q': {1: 90, 2: 12, 3: 11},
#  'S': {1: 70, 2: 20, 3: 15}}
# ```

# %%
titanic_df.groupby(["Embarked","Pclass"]).agg({"Fare":"mean"}).round(2)
# Out:
#                    Fare
# Embarked Pclass
# C        1       104.72
#          2        25.36
#          3        11.21
# Q        1        90.00
#          2        12.35
#          3        11.18
# S        1        70.51
#          2        20.33
#          3        14.64

# %% [markdown]
# ## **Questions Based on Fifa Worldcup - 2022 Dataset:**
#
# You can read the dataset by using the below sample code
#
# ```python
# import pandas as pd
#
# fifa_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv")
# ```

# %% [markdown]
# ### `Q-4:` Perform `groupby` based on the `"Team"` column and then perform Z Normalization on top of the below columns of each group:
# 1. Passes
# 2. Passes Completed
# 3. Attempted Line Breaks
# 4. Completed Line Breaks
#
# You have to make a python function named `z_normalization` which takes two arguments:
#
# 1. *group:* Every group that you have created
# 2. *cols_to_perform:* This parameter takes a list of columns on which you have to perform the Z-Normalization.
#
# For this problem, you have to use th `apply()` method.
#
# $\Large Z \ - \ Normalization = \frac{X_i - \mu}{std} $
#
# After that find out the below values for each group:
# - minimum "Passess"
# - maximum "Passess"
# - minimum "Yellow Cards"
# - maximum "Yellow cards"
# - average "Yellow Cards"
# - maximum "Attempted Line Breaks"
# - minimum "Attempted Line Breaks"
# - standardard deviation of "Attempted Line Breaks"
# - average Possession

# %%
fifa = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv")
print(fifa.head())
fifa.columns
# Out:
#    Sl. No  Match No.     Team      Against Group  Goal  Possession (%)  \
# 0       1          1    Qatar      Ecuador     A     0              40
# 1       2          1  Ecuador        Qatar     A     2              46
# 2       3          2  England         Iran     B     6              69
# 3       4          2     Iran      England     B     2              20
# 4       5          3  Senegal  Netherlands     A     0              39
#
#    Inside Penalty Area  Outside Penalty Area  Assists  ...  Fouls Against  \
# 0                    0                     0        0  ...             15
# 1                    2                     0        1  ...             15
# 2                    6                     0        6  ...              9
# 3                    2                     0        1  ...             14
# 4                    0                     0        0  ...             13
#
#    Offsides  Passes  Passes Completed  Crosses  Crosses Completed  Corners  \
# 0         3     453               387       10                  5        1
# 1         4     484               419       26                 10        3
# 2         2     810               733       29                  9        8
# 3         2     232               156       11                  3        0
# 4         2     391               326       22                  8        6
#
#    Free Kicks  Penalties Scored  Pts
# 0          19                 0    0
# 1          17                 1    3
# 2          16                 0    3
# 3          10                 1    0
# 4          14                 0    0
#
# [5 rows x 38 columns]
# Index(['Sl. No', 'Match No.', 'Team', 'Against', 'Group', 'Goal',
#        'Possession (%)', 'Inside Penalty Area', 'Outside Penalty Area',
#        'Assists', 'Total Attempts', 'On Target', 'Off Target',
#        'Target in Penalty', 'Target from Outside', 'Left Channel',
#        'Left Inside Channel', 'Central Channel', 'Right Inside Channel',
#        'Right Channel', 'Receptions MD', 'Receptions D',
#        'Attempted Line Breaks', 'Completed Line Breaks',
#        'Attempted Defensive Line Breaks', 'Completed Defensive Line Breaks',
#        'Yellow Cards', 'Red Cards', 'Fouls Against', 'Offsides', 'Passes',
#        'Passes Completed', 'Crosses', 'Crosses Completed', 'Corners',
#        'Free Kicks', 'Penalties Scored', 'Pts'],
#       dtype='object')

# %%
def z_norm(group,cols):
  group[cols]=(group[cols]-group[cols].mean())/group[cols].std()
  return group

cols_to_norm=["Passes","Passes Completed",'Attempted Line Breaks', 'Completed Line Breaks']
fifanorm=fifa.groupby("Team",group_keys=False).apply(z_norm,cols=cols_to_norm)
fifanorm.groupby("Team").agg({"Passes":("min","max"),"Yellow Cards":("min","max","mean"),"Attempted Line Breaks":("max","min","std"),"Possession (%)":"mean"})
# Out:
# /tmp/ipython-input-822468950.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   fifanorm=fifa.groupby("Team",group_keys=False).apply(z_norm,cols=cols_to_norm)
#                   Passes           Yellow Cards                \
#                      min       max          min max      mean
# Team
# Argentina      -1.510257  1.685214            0   8  2.285714
# Australia      -1.114789  0.932782            0   3  1.750000
# Belgium        -1.082696  0.888950            1   3  1.666667
# Brazil         -0.928871  1.609122            0   3  1.200000
# Cameroon       -0.875605  1.089713            1   5  2.666667
# Canada         -1.120897  0.800641            2   4  2.666667
# Costa Rica     -1.013178  0.986279            1   3  2.000000
# Croatia        -1.441280  1.093005            0   2  1.142857
# Denmark        -1.046208  0.946290            1   2  1.666667
# Ecuador        -0.883020  1.085876            0   2  1.000000
# England        -0.877731  1.705844            0   1  0.200000
# France         -1.219077  1.571019            0   3  1.142857
# Germany        -1.131449  0.765392            0   3  1.000000
# Ghana          -1.045786  0.946861            2   4  2.666667
# Iran           -0.820695  1.113800            2   3  2.333333
# Japan          -1.001479  0.979825            0   3  1.500000
# Korea Republic -1.157924  0.877868            1   2  1.500000
# Mexico         -0.918398  1.065342            1   4  2.333333
# Morocco        -1.384362  1.662218            0   3  1.285714
# Netherlands    -1.051749  1.428668            0   4  1.800000
# Poland         -0.694755  1.483035            1   3  1.750000
# Portugal       -1.646177  1.035658            0   3  1.200000
# Qatar          -1.147558  0.684833            0   4  2.333333
# Saudi Arabia   -0.667896  1.149691            2   6  4.666667
# Senegal        -1.214144  1.235077            1   3  1.750000
# Serbia         -1.089807  0.875419            2   7  4.000000
# Spain          -1.498758  0.554601            0   1  0.500000
# Switzerland    -1.469082  0.754945            1   4  2.250000
# Tunisia        -0.965692  1.031097            1   3  1.666667
# United States  -1.136338  0.860862            0   4  1.250000
# Uruguay        -0.931702  1.056570            1   3  2.000000
# Wales          -0.971590  1.026174            1   2  1.666667
#
#                Attempted Line Breaks                Possession (%)
#                                  max       min  std           mean
# Team
# Argentina                   1.757406 -1.027917  1.0      49.285714
# Australia                   0.961409 -1.187623  1.0      31.250000
# Belgium                     1.109400 -0.832050  1.0      49.000000
# Brazil                      1.085013 -1.627519  1.0      50.400000
# Cameroon                    0.788942 -1.124661  1.0      38.333333
# Canada                      0.865260 -1.094819  1.0      44.333333
# Costa Rica                  0.590132 -1.154606  1.0      27.333333
# Croatia                     1.187420 -1.785063  1.0      47.428571
# Denmark                     1.000000 -1.000000  1.0      51.333333
# Ecuador                     1.019020 -0.979827  1.0      42.666667
# England                     1.354603 -1.172641  1.0      57.200000
# France                      1.147789 -1.327966  1.0      44.857143
# Germany                     1.036065 -0.959538  1.0      53.000000
# Ghana                       0.979199 -1.019578  1.0      37.000000
# Iran                        0.640642 -1.152297  1.0      31.666667
# Japan                       1.377855 -0.948495  1.0      30.250000
# Korea Republic              0.840338 -1.449814  1.0      42.250000
# Mexico                      0.589590 -1.154613  1.0      46.666667
# Morocco                     1.006855 -1.718366  1.0      34.285714
# Netherlands                 1.128588 -1.222637  1.0      44.000000
# Poland                      0.626272 -1.493418  1.0      32.000000
# Portugal                    1.655185 -0.796941  1.0      53.800000
# Qatar                       1.115767 -0.815368  1.0      39.333333
# Saudi Arabia                0.976238 -1.022179  1.0      36.666667
# Senegal                     1.343085 -1.077420  1.0      38.500000
# Serbia                      1.066614 -0.916387  1.0      42.666667
# Spain                       1.193911 -0.905726  1.0      67.000000
# Switzerland                 1.024097 -1.300880  1.0      43.000000
# Tunisia                     0.805353 -1.119304  1.0      38.666667
# United States               0.767335 -1.435367  1.0      47.000000
# Uruguay                     1.149932 -0.665750  1.0      41.000000
# Wales                       0.867461 -1.093756  1.0      41.000000

# %% [markdown]
# ## **Questions on IPL wala dataset**
#
# ball by ball dataset - https://drive.google.com/file/d/1-kvv_9KCSAFWcrhS9WgTxSrURkRh6GNt/view?usp=share_link

# %%
ipl=pd.read_csv("/content/ipl_deliveries.csv")
ipl.head(15)
# Out:
#          ID                            Team  innings  overs  ballnumber  \
# 0   1312200  Rajasthan RoyalsGujarat Titans        1      0           1
# 1   1312200  Rajasthan RoyalsGujarat Titans        1      0           2
# 2   1312200  Rajasthan RoyalsGujarat Titans        1      0           3
# 3   1312200  Rajasthan RoyalsGujarat Titans        1      0           4
# 4   1312200  Rajasthan RoyalsGujarat Titans        1      0           5
# 5   1312200  Rajasthan RoyalsGujarat Titans        1      0           6
# 6   1312200  Rajasthan RoyalsGujarat Titans        1      1           1
# 7   1312200  Rajasthan RoyalsGujarat Titans        1      1           2
# 8   1312200  Rajasthan RoyalsGujarat Titans        1      1           3
# 9   1312200  Rajasthan RoyalsGujarat Titans        1      1           4
# 10  1312200  Rajasthan RoyalsGujarat Titans        1      1           5
# 11  1312200  Rajasthan RoyalsGujarat Titans        1      1           6
# 12  1312200  Rajasthan RoyalsGujarat Titans        1      2           1
# 13  1312200  Rajasthan RoyalsGujarat Titans        1      2           2
# 14  1312200  Rajasthan RoyalsGujarat Titans        1      2           3
#
#          batter          bowler  non-striker extra_type  batsman_run  \
# 0   YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 1   YBK Jaiswal  Mohammed Shami   JC Buttler    legbyes            0
# 2    JC Buttler  Mohammed Shami  YBK Jaiswal        NaN            1
# 3   YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 4   YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 5   YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 6    JC Buttler      Yash Dayal  YBK Jaiswal        NaN            0
# 7    JC Buttler      Yash Dayal  YBK Jaiswal        NaN            0
# 8    JC Buttler      Yash Dayal  YBK Jaiswal        NaN            4
# 9    JC Buttler      Yash Dayal  YBK Jaiswal        NaN            0
# 10   JC Buttler      Yash Dayal  YBK Jaiswal        NaN            1
# 11  YBK Jaiswal      Yash Dayal   JC Buttler        NaN            0
# 12   JC Buttler  Mohammed Shami  YBK Jaiswal        NaN            1
# 13  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 14  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            4
#
#     extras_run  total_run  non_boundary  isWicketDelivery player_out kind  \
# 0            0          0             0                 0        NaN  NaN
# 1            1          1             0                 0        NaN  NaN
# 2            0          1             0                 0        NaN  NaN
# 3            0          0             0                 0        NaN  NaN
# 4            0          0             0                 0        NaN  NaN
# 5            0          0             0                 0        NaN  NaN
# 6            0          0             0                 0        NaN  NaN
# 7            0          0             0                 0        NaN  NaN
# 8            0          4             0                 0        NaN  NaN
# 9            0          0             0                 0        NaN  NaN
# 10           0          1             0                 0        NaN  NaN
# 11           0          0             0                 0        NaN  NaN
# 12           0          1             0                 0        NaN  NaN
# 13           0          0             0                 0        NaN  NaN
# 14           0          4             0                 0        NaN  NaN
#
#    fielders_involved       BattingTeam     BowlingTeam
# 0                NaN  Rajasthan Royals  Gujarat Titans
# 1                NaN  Rajasthan Royals  Gujarat Titans
# 2                NaN  Rajasthan Royals  Gujarat Titans
# 3                NaN  Rajasthan Royals  Gujarat Titans
# 4                NaN  Rajasthan Royals  Gujarat Titans
# 5                NaN  Rajasthan Royals  Gujarat Titans
# 6                NaN  Rajasthan Royals  Gujarat Titans
# 7                NaN  Rajasthan Royals  Gujarat Titans
# 8                NaN  Rajasthan Royals  Gujarat Titans
# 9                NaN  Rajasthan Royals  Gujarat Titans
# 10               NaN  Rajasthan Royals  Gujarat Titans
# 11               NaN  Rajasthan Royals  Gujarat Titans
# 12               NaN  Rajasthan Royals  Gujarat Titans
# 13               NaN  Rajasthan Royals  Gujarat Titans
# 14               NaN  Rajasthan Royals  Gujarat Titans

# %% [markdown]
# ###`Q-5:` Find batsman in below category-
# * Highest score while chasing
# * Best Strike rate while chasing and have faced 100+ balls
#
#
# > Chasing mean team batting in second inning

# %%
total_chase_runs=ipl[ipl["innings"]==2].groupby("batter").agg({"batsman_run":"sum"}).sort_values(by="batsman_run",ascending=False)
total_chase_runs.head()
# Out:
#             batsman_run
# batter
# V Kohli            3070
# DA Warner          2839
# RV Uthappa         2832
# S Dhawan           2707
# RG Sharma          2464

# %%
total_chase_balls=ipl[ipl["innings"]==2]["batter"].value_counts()
total_chase_balls
# Out:
# batter
# V Kohli         2414
# S Dhawan        2198
# RV Uthappa      2173
# G Gambhir       2116
# RG Sharma       2056
#                 ...
# C Nanda            1
# S Lamichhane       1
# GC Viljoen         1
# AN Ghosh           1
# PN Mankad          1
# Name: count, Length: 552, dtype: int64

# %%
chasing_batsmen=total_chase_runs.join(total_chase_balls)
chasing_batsmen["strike_rate"]=(chasing_batsmen["batsman_run"]/chasing_batsmen["count"])*100
chasing_batsmen[chasing_batsmen["count"]>100].sort_values(by="strike_rate",ascending=False)
# Out:
#                 batsman_run  count  strike_rate
# batter
# PJ Cummins              222    119   186.554622
# LS Livingstone          182    111   163.963964
# AD Russell              986    605   162.975207
# SP Narine               599    376   159.308511
# V Sehwag               1427    906   157.505519
# ...                     ...    ...          ...
# LR Shukla               137    149    91.946309
# R Dhawan                 92    102    90.196078
# GH Vihari               179    200    89.500000
# B Kumar                 150    168    89.285714
# K Goel                   97    122    79.508197
#
# [184 rows x 3 columns]

# %%
ipl.sample(1)
# Out:
#             ID                                        Team  innings  overs  \
# 198933  392239  Royal Challengers BangaloreDeccan Chargers        1     11
#
#         ballnumber     batter            bowler non-striker extra_type  \
# 198933           6  RG Sharma  RE van der Merwe    HH Gibbs        NaN
#
#         batsman_run  extras_run  total_run  non_boundary  isWicketDelivery  \
# 198933            0           0          0             0                 0
#
#        player_out kind fielders_involved      BattingTeam  \
# 198933        NaN  NaN               NaN  Deccan Chargers
#
#                         BowlingTeam
# 198933  Royal Challengers Bangalore

# %% [markdown]
# ###`Q-6` Most Successful bowler against any batsman. Find that pair of bowler and batsman.
# > Most Successful in terms of dissmissal. A bowler who have dissmissed any batsman most no of times. If any two pairs have same no of dissmisal, consider runs conceded by bowler to that batsman. Those who have concede lesser runs is more successful.

# %%
ipl.groupby(["bowler","batter"]).agg({"isWicketDelivery":"sum","batsman_run":"sum"}).sort_values(by=["isWicketDelivery","batsman_run"], ascending=[False,True]).head(1)
# Out:
#                      isWicketDelivery  batsman_run
# bowler    batter
# SP Narine RG Sharma                 8          137

# %% [markdown]
# ###`Q-7`: Most successful batting pair in IPL. Batting pair who have scored most runs playing together.

# %%
ipl["pairs"]=ipl[["batter","non-striker"]].apply(lambda x: tuple(sorted(([x[0],x[1]]))) ,axis=1)
ipl['pairs']
# Out:
# /tmp/ipython-input-4210175502.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ipl["pairs"]=ipl[["batter","non-striker"]].apply(lambda x: tuple(sorted(([x[0],x[1]]))) ,axis=1)
# 0         (JC Buttler, YBK Jaiswal)
# 1         (JC Buttler, YBK Jaiswal)
# 2         (JC Buttler, YBK Jaiswal)
# 3         (JC Buttler, YBK Jaiswal)
# 4         (JC Buttler, YBK Jaiswal)
#                     ...
# 225949          (P Kumar, SB Joshi)
# 225950          (P Kumar, SB Joshi)
# 225951          (P Kumar, SB Joshi)
# 225952          (P Kumar, SB Joshi)
# 225953          (P Kumar, SB Joshi)
# Name: pairs, Length: 225954, dtype: object

# %%
ipl.groupby("pairs")["total_run"].sum().sort_values(ascending=False)
# Out:
# pairs
# (AB de Villiers, V Kohli)    3134
# (CH Gayle, V Kohli)          2802
# (DA Warner, S Dhawan)        2357
# (G Gambhir, RV Uthappa)      1906
# (KL Rahul, MA Agarwal)       1731
#                              ...
# (A Choudhary, S Badree)         0
# (T Stubbs, Tilak Varma)         0
# (A Mishra, CL White)            0
# (M Muralitharan, MS Gony)       0
# (M Morkel, S Nadeem)            0
# Name: total_run, Length: 4259, dtype: int64

# %% [markdown]
# ###`Q-8:` Make a dataframe for all batting pairs played together.
# ```
# Batsman1 Batsman2 Runs Avg StrikeRate
# ```
#
# > Just to ease this question you can count wide-balls for strike rate.

# %%
pair=ipl.groupby("pairs").agg({"total_run":["sum","mean"],}).sort_values(by=("total_run","sum"), ascending=False)
pair["strike_rate"]=pair[("total_run","mean")]*100
pair
# Out:
#                           total_run           strike_rate
#                                 sum      mean
# pairs
# (AB de Villiers, V Kohli)      3134  1.522098  152.209811
# (CH Gayle, V Kohli)            2802  1.420172  142.017233
# (DA Warner, S Dhawan)          2357  1.366377  136.637681
# (G Gambhir, RV Uthappa)        1906  1.337544  133.754386
# (KL Rahul, MA Agarwal)         1731  1.429397  142.939719
# ...                             ...       ...         ...
# (A Choudhary, S Badree)           0  0.000000    0.000000
# (T Stubbs, Tilak Varma)           0  0.000000    0.000000
# (A Mishra, CL White)              0  0.000000    0.000000
# (M Muralitharan, MS Gony)         0  0.000000    0.000000
# (M Morkel, S Nadeem)              0  0.000000    0.000000
#
# [4259 rows x 3 columns]
