# %% [markdown]
# Given a list of dictionaries representing people, filter the list to include only those older than 30, and then create a new list containing their full names.

# %%
people = [
    {'first_name': 'John', 'last_name': 'Doe', 'age': 28},
    {'first_name': 'Jane', 'last_name': 'Smith', 'age': 34},
    {'first_name': 'Peter', 'last_name': 'Jones', 'age': 45}
]
ol=[]
for i in people:
  if i["age"]>30:
    ol.append(f'{i["first_name"]} {i["last_name"]}')
print(ol)
# Out:
# ['Jane Smith', 'Peter Jones']

# %%
#using list comprehension:
ol=[f"{p["first_name"]} {p["last_name"]}" for p in people if p["age"]>30]
ol
# Out:
# ['Jane Smith', 'Peter Jones']

# %% [markdown]
# Given a DataFrame of sales data, find the total Sales for each Category.

# %%
import pandas as pd
sales_data = pd.DataFrame({
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Books', 'Clothing'],
    'Sales': [1200, 300, 800, 150, 450]
})

sales_data.groupby("Category").sum()
# Out:
#              Sales
# Category
# Books          150
# Clothing       750
# Electronics   2000

# %% [markdown]
# Given a NumPy array of temperatures in Celsius, convert all of them to Fahrenheit without using a for loop. The formula is F=C×5/9+32.

# %%
import numpy as np
celsius_temps = np.array([0, 10, 25, 30, 100])

ftemps=((celsius_temps*9)/5 +32)
print(ftemps)
# Out:
# [ 32.  50.  77.  86. 212.]

# %% [markdown]
#  Group-wise Normalization with .transform()
# Given a DataFrame of student scores in different subjects, calculate the "z-score" for each student's score relative to the mean and standard deviation of their own subject. The formula for z-score is (x−mean)/std_dev.

# %%
import pandas as pd
scores_df = pd.DataFrame({
    'Subject': ['Math', 'Math', 'Science', 'Science', 'Math'],
    'Score': [88, 95, 76, 85, 79]
})
scores_df["Zscore"]=scores_df.groupby("Subject")["Score"].transform(lambda x: (x-x.mean())/x.std())

scores_df["zscore"]=(scores_df["Score"]-scores_df["Score"].mean())/scores_df["Score"].std()
scores_df
# Out:
#    Subject  Score    Zscore    zscore
# 0     Math     88  0.083117  0.453132
# 1     Math     95  0.955847  1.386051
# 2  Science     76 -0.707107 -1.146157
# 3  Science     85  0.707107  0.053310
# 4     Math     79 -1.038965 -0.746335

# %% [markdown]
# Using the Titanic dataset, find the 3 most common titles (Mr., Mrs., etc.) for passengers who embarked at port 'S' (Southampton) and were under the age of 40.

# %%
titanic=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv")
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 93            94         0       3               Dean, Mr. Bertram Frank
# 541          542         0       3  Andersson, Miss. Ingeborg Constanzia
# 535          536         1       2                Hart, Miss. Eva Miriam
# 744          745         1       3                    Stranden, Mr. Juho
# 686          687         0       3              Panula, Mr. Jaako Arnold
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 93     male  26.0      1      2          C.A. 2315  20.5750   NaN        S
# 541  female   9.0      4      2             347082  31.2750   NaN        S
# 535  female   7.0      0      2       F.C.C. 13529  26.2500   NaN        S
# 744    male  31.0      0      0  STON/O 2. 3101288   7.9250   NaN        S
# 686    male  14.0      4      1            3101295  39.6875   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic[(titanic["Embarked"]=="S") & (titanic["Age"]<40)]["Name"].str.extract("([A-Za-z]+)\.").value_counts()[:3]
#now how do I extract just the titles.
#after understanding how regex works:
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipython-input-3341871393.py:1: SyntaxWarning: invalid escape sequence '\.'
#   titanic[(titanic["Embarked"]=="S") & (titanic["Age"]<40)]["Name"].str.extract("([A-Za-z]+)\.").value_counts()[:3]
# 0
# Mr      251
# Miss     93
# Mrs      54
# Name: count, dtype: int64

# %% [markdown]
# Given a DataFrame with a date column as strings, convert it to a proper datetime object. Then, create new columns for the 'Year' and 'Month'. Finally, find the total Sales for each month.

# %%
import pandas as pd
sales_df = pd.DataFrame({
    'Date': ['2025-01-15', '2025-01-22', '2025-02-05', '2025-02-12'],
    'Sales': [100, 150, 200, 50]
})
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4 non-null      object
#  1   Sales   4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
sales_df["Date"]=pd.to_datetime(sales_df["Date"])
sales_df["Year"]=sales_df['Date'].dt.year
sales_df["Month"]=sales_df['Date'].dt.month
sales_df.groupby("Month").agg({"Sales":"sum"})
# Out:
#        Sales
# Month
# 1        250
# 2        250

# %% [markdown]
# Given a DataFrame of bank transactions, calculate the running balance for each CustomerID. The balance should restart for each new customer.

# %%
import pandas as pd
transactions_df = pd.DataFrame({
    'CustomerID': [1, 1, 2, 1, 2, 2],
    'Amount': [100, -20, 50, 30, -10, 80]
})
transactions_df["running_bal"]=transactions_df.groupby("CustomerID").cumsum()
transactions_df
# Out:
#    CustomerID  Amount  running_bal
# 0           1     100          100
# 1           1     -20           80
# 2           2      50           50
# 3           1      30          110
# 4           2     -10           40
# 5           2      80          120

# %% [markdown]
# Given a DataFrame of employee salaries by department, find the employee with the second-highest salary in each department.

# %%
import pandas as pd
employees_df = pd.DataFrame({
    'Department': ['IT', 'IT', 'Sales', 'Sales', 'IT', 'Sales'],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank'],
    'Salary': [90000, 85000, 70000, 80000, 92000, 72000]
})

employees_df.groupby("Department").apply(lambda x: x.sort_values(by="Salary",ascending=False).iloc[1])
# Out:
# /tmp/ipython-input-4214242982.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   employees_df.groupby("Department").apply(lambda x: x.sort_values(by="Salary",ascending=False).iloc[1])
#            Department   Name  Salary
# Department
# IT                 IT  Alice   90000
# Sales           Sales  Frank   72000
